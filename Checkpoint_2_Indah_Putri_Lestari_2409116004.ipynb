# %% [markdown]
# Sumber dataset : https://www.kaggle.com/datasets/himelsarder/cinema-hall-ticket-sales-and-customer-behavior

# %% [markdown]
# ## Library

# %%
import pandas as pd

# %% [markdown]
# ## Membaca Data

# %%
df = pd.read_csv("/content/drive/MyDrive/PANDAS/cinema_hall_ticket_sales.csv")

df
# Out:
#      Ticket_ID  Age  Ticket_Price Movie_Genre Seat_Type Number_of_Person  \
# 0        N4369   55         12.27      Comedy  Standard                7
# 1        B8091   35         19.02       Drama  Standard            Alone
# 2        V6341   55         22.52      Horror       VIP                3
# 3        B3243   53         23.01       Drama  Standard                6
# 4        I3814   30         21.81      Comedy       VIP                4
# ...        ...  ...           ...         ...       ...              ...
# 1435     E5406   41         17.09      Sci-Fi  Standard                2
# 1436     C4357   19         11.45      Action  Standard            Alone
# 1437     R7285   53         17.13      Comedy   Premium            Alone
# 1438     W6360   34         20.25      Comedy   Premium                2
# 1439     Z8034   60         21.90      Action       VIP            Alone
#
#      Purchase_Again
# 0                No
# 1               Yes
# 2                No
# 3               Yes
# 4               Yes
# ...             ...
# 1435            Yes
# 1436             No
# 1437            Yes
# 1438            Yes
# 1439             No
#
# [1440 rows x 7 columns]

# %% [markdown]
# # **DATA UNDERSTUNDING**

# %% [markdown]
# ## Pengecekan Struktur Data

# %%
print("\nTipe data setiap kolom dalam data ini: ")
df.dtypes
# Out:
# Tipe data setiap kolom dalam data ini:
# Ticket_ID            object
# Age                   int64
# Ticket_Price        float64
# Movie_Genre          object
# Seat_Type            object
# Number_of_Person     object
# Purchase_Again       object
# dtype: object

# %%
print("\nJumlah baris dan kolom dalam data ini: ")
df.shape
# Out:
# Jumlah baris dan kolom dalam data ini:
# (1440, 7)

# %%
print("\nStatistik deskriptif data ini: ")
df.describe()
# Out:
# Statistik deskriptif data ini:
#                Age  Ticket_Price  Number_of_Person  Purchase_Again  \
# count  1440.000000   1440.000000       1440.000000     1440.000000
# mean     38.904861     17.383972          2.881944        0.490972
# std      12.426293      4.397087          2.192591        0.500092
# min      18.000000     10.010000          1.000000        0.000000
# 25%      28.000000     13.640000          1.000000        0.000000
# 50%      39.000000     17.280000          2.000000        0.000000
# 75%      50.000000     21.392500          5.000000        1.000000
# max      60.000000     24.990000          7.000000        1.000000
#
#        Total_Harga_Tiket
# count        1440.000000
# mean           50.050250
# std            41.465089
# min            10.020000
# 25%            17.760000
# 50%            26.350000
# 75%            74.975000
# max           174.720000

# %%
print('\nKorelasi antar kolom numerik: ')
df.corr(numeric_only=True)
# Out:
# Korelasi antar kolom numerik:
#                         Age  Ticket_Price  Number_of_Person  Purchase_Again  \
# Age                1.000000      0.036528         -0.010283        0.023401
# Ticket_Price       0.036528      1.000000         -0.005127       -0.022706
# Number_of_Person  -0.010283     -0.005127          1.000000       -0.015549
# Purchase_Again     0.023401     -0.022706         -0.015549        1.000000
# Total_Harga_Tiket  0.006286      0.304393          0.921225       -0.022338
#
#                    Total_Harga_Tiket
# Age                         0.006286
# Ticket_Price                0.304393
# Number_of_Person            0.921225
# Purchase_Again             -0.022338
# Total_Harga_Tiket           1.000000

# %% [markdown]
# # **DATA PREPARATION**

# %% [markdown]
# ## Missing Values

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Ticket_ID           0.0
# Age                 0.0
# Ticket_Price        0.0
# Movie_Genre         0.0
# Seat_Type           0.0
# Number_of_Person    0.0
# Purchase_Again      0.0
# dtype: float64

# %% [markdown]
# # Duplicated Values

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Ticket_ID, Age, Ticket_Price, Movie_Genre, Seat_Type, Number_of_Person, Purchase_Again]
# Index: []

# %% [markdown]
# # Outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom              Persentase Outliers
# Age                           0.000000
# Ticket_Price                  0.000000
# Number_of_Person              0.000000
# Purchase_Again                0.000000
# Total_Harga_Tiket             1.666667

# %%
df
# Out:
#       Age  Ticket_Price Movie_Genre Seat_Type  Number_of_Person  \
# 0      55         12.27      Comedy  Standard                 7
# 1      35         19.02       Drama  Standard                 1
# 2      55         22.52      Horror       VIP                 3
# 3      53         23.01       Drama  Standard                 6
# 4      30         21.81      Comedy       VIP                 4
# ...   ...           ...         ...       ...               ...
# 1435   41         17.09      Sci-Fi  Standard                 2
# 1436   19         11.45      Action  Standard                 1
# 1437   53         17.13      Comedy   Premium                 1
# 1438   34         20.25      Comedy   Premium                 2
# 1439   60         21.90      Action       VIP                 1
#
#       Purchase_Again  Total_Harga_Tiket
# 0                  0              85.89
# 1                  1              19.02
# 2                  0              67.56
# 3                  1             138.06
# 4                  1              87.24
# ...              ...                ...
# 1435               1              34.18
# 1436               0              11.45
# 1437               1              17.13
# 1438               1              40.50
# 1439               0              21.90
#
# [1440 rows x 7 columns]

# %% [markdown]
# Melakukan Imputasi

# %%
columns_to_impute = ["Total_Harga_Tiket"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom              Persentase Outliers
# Age                                0.0
# Ticket_Price                       0.0
# Number_of_Person                   0.0
# Purchase_Again                     0.0
# Total_Harga_Tiket                  0.0

# %%
df
# Out:
#       Age  Ticket_Price Movie_Genre Seat_Type  Number_of_Person  \
# 0      55         12.27      Comedy  Standard                 7
# 1      35         19.02       Drama  Standard                 1
# 2      55         22.52      Horror       VIP                 3
# 3      53         23.01       Drama  Standard                 6
# 4      30         21.81      Comedy       VIP                 4
# ...   ...           ...         ...       ...               ...
# 1435   41         17.09      Sci-Fi  Standard                 2
# 1436   19         11.45      Action  Standard                 1
# 1437   53         17.13      Comedy   Premium                 1
# 1438   34         20.25      Comedy   Premium                 2
# 1439   60         21.90      Action       VIP                 1
#
#       Purchase_Again  Total_Harga_Tiket
# 0                  0              85.89
# 1                  1              19.02
# 2                  0              67.56
# 3                  1             138.06
# 4                  1              87.24
# ...              ...                ...
# 1435               1              34.18
# 1436               0              11.45
# 1437               1              17.13
# 1438               1              40.50
# 1439               0              21.90
#
# [1440 rows x 7 columns]

# %% [markdown]
# ## Incosistent Value

# %%
df
# Out:
#      Ticket_ID  Age  Ticket_Price Movie_Genre Seat_Type Number_of_Person  \
# 0        N4369   55         12.27      Comedy  Standard                7
# 1        B8091   35         19.02       Drama  Standard            Alone
# 2        V6341   55         22.52      Horror       VIP                3
# 3        B3243   53         23.01       Drama  Standard                6
# 4        I3814   30         21.81      Comedy       VIP                4
# ...        ...  ...           ...         ...       ...              ...
# 1435     E5406   41         17.09      Sci-Fi  Standard                2
# 1436     C4357   19         11.45      Action  Standard            Alone
# 1437     R7285   53         17.13      Comedy   Premium            Alone
# 1438     W6360   34         20.25      Comedy   Premium                2
# 1439     Z8034   60         21.90      Action       VIP            Alone
#
#      Purchase_Again
# 0                No
# 1               Yes
# 2                No
# 3               Yes
# 4               Yes
# ...             ...
# 1435            Yes
# 1436             No
# 1437            Yes
# 1438            Yes
# 1439             No
#
# [1440 rows x 7 columns]

# %% [markdown]
# Mengubah pada kolom Number_of_Person yang sebelumnya terdapat objek "Alone" akan diubah menjadi 1.

# %%
df["Number_of_Person"] = pd.to_numeric(df["Number_of_Person"], errors="coerce")
df["Number_of_Person"] = df["Number_of_Person"].fillna(0).astype(int)
df["Number_of_Person"] = df['Number_of_Person'].replace(0,1)

df
# Out:
#      Ticket_ID  Age  Ticket_Price Movie_Genre Seat_Type  Number_of_Person  \
# 0        N4369   55         12.27      Comedy  Standard                 7
# 1        B8091   35         19.02       Drama  Standard                 1
# 2        V6341   55         22.52      Horror       VIP                 3
# 3        B3243   53         23.01       Drama  Standard                 6
# 4        I3814   30         21.81      Comedy       VIP                 4
# ...        ...  ...           ...         ...       ...               ...
# 1435     E5406   41         17.09      Sci-Fi  Standard                 2
# 1436     C4357   19         11.45      Action  Standard                 1
# 1437     R7285   53         17.13      Comedy   Premium                 1
# 1438     W6360   34         20.25      Comedy   Premium                 2
# 1439     Z8034   60         21.90      Action       VIP                 1
#
#      Purchase_Again
# 0                No
# 1               Yes
# 2                No
# 3               Yes
# 4               Yes
# ...             ...
# 1435            Yes
# 1436             No
# 1437            Yes
# 1438            Yes
# 1439             No
#
# [1440 rows x 7 columns]

# %% [markdown]
# Mengubah tipe data yang sebelumnya string menjadi int pada kolom Purchase_Again.

# %%
df['Purchase_Again'] = df['Purchase_Again'].replace({'Yes': 1, 'No': 0}).astype(int)

df
# Out:
#      Ticket_ID  Age  Ticket_Price Movie_Genre Seat_Type  Number_of_Person  \
# 0        N4369   55         12.27      Comedy  Standard                 7
# 1        B8091   35         19.02       Drama  Standard                 1
# 2        V6341   55         22.52      Horror       VIP                 3
# 3        B3243   53         23.01       Drama  Standard                 6
# 4        I3814   30         21.81      Comedy       VIP                 4
# ...        ...  ...           ...         ...       ...               ...
# 1435     E5406   41         17.09      Sci-Fi  Standard                 2
# 1436     C4357   19         11.45      Action  Standard                 1
# 1437     R7285   53         17.13      Comedy   Premium                 1
# 1438     W6360   34         20.25      Comedy   Premium                 2
# 1439     Z8034   60         21.90      Action       VIP                 1
#
#       Purchase_Again
# 0                  0
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 1435               1
# 1436               0
# 1437               1
# 1438               1
# 1439               0
#
# [1440 rows x 7 columns]

# %% [markdown]
# ## Construct Data

# %%
df['Total_Harga_Tiket'] = df['Ticket_Price'] * df['Number_of_Person']

print(df.head())
# Out:
#   Ticket_ID  Age  Ticket_Price Movie_Genre Seat_Type  Number_of_Person  \
# 0     N4369   55         12.27      Comedy  Standard                 7
# 1     B8091   35         19.02       Drama  Standard                 1
# 2     V6341   55         22.52      Horror       VIP                 3
# 3     B3243   53         23.01       Drama  Standard                 6
# 4     I3814   30         21.81      Comedy       VIP                 4
#
#    Purchase_Again  Total_Harga_Tiket
# 0               0              85.89
# 1               1              19.02
# 2               0              67.56
# 3               1             138.06
# 4               1              87.24

# %% [markdown]
# ## Data Reduction

# %%
df = df.drop('Ticket_ID', axis=1, errors='ignore')

df
# Out:
#       Age  Ticket_Price Movie_Genre Seat_Type  Number_of_Person  \
# 0      55         12.27      Comedy  Standard                 7
# 1      35         19.02       Drama  Standard                 1
# 2      55         22.52      Horror       VIP                 3
# 3      53         23.01       Drama  Standard                 6
# 4      30         21.81      Comedy       VIP                 4
# ...   ...           ...         ...       ...               ...
# 1435   41         17.09      Sci-Fi  Standard                 2
# 1436   19         11.45      Action  Standard                 1
# 1437   53         17.13      Comedy   Premium                 1
# 1438   34         20.25      Comedy   Premium                 2
# 1439   60         21.90      Action       VIP                 1
#
#       Purchase_Again  Total_Harga_Tiket
# 0                  0              85.89
# 1                  1              19.02
# 2                  0              67.56
# 3                  1             138.06
# 4                  1              87.24
# ...              ...                ...
# 1435               1              34.18
# 1436               0              11.45
# 1437               1              17.13
# 1438               1              40.50
# 1439               0              21.90
#
# [1440 rows x 7 columns]
